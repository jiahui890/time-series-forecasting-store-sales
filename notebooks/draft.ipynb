# %%
import pandas as pd

# %%
path='C:/Users/FT-LT74/Desktop/notes/github/time-series-forecasting-store-sales/data/interim/'
#path='C:/Users/jiahu/Desktop/Data Science Sample Prac/github_repos/time-series-forecasting-store-sales/data/interim/'

# %%
df=pd.read_csv(path+'merged_df.csv')
df
# Out:
# C:\Users\FT-LT74\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (12,13,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3008770  3000883  2017-08-15          9                     POULTRY   438.133
# 3008771  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3008772  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3008773  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3008774  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state store_type  cluster  transactions  \
# 0                  0  Quito  Pichincha          D       13           NaN
# 1                  0  Quito  Pichincha          D       13           NaN
# 2                  0  Quito  Pichincha          D       13           NaN
# 3                  0  Quito  Pichincha          D       13           NaN
# 4                  0  Quito  Pichincha          D       13           NaN
# ...              ...    ...        ...        ...      ...           ...
# 3008770            0  Quito  Pichincha          B        6        2155.0
# 3008771            1  Quito  Pichincha          B        6        2155.0
# 3008772          148  Quito  Pichincha          B        6        2155.0
# 3008773            8  Quito  Pichincha          B        6        2155.0
# 3008774            0  Quito  Pichincha          B        6        2155.0
#
#          dcoilwtico holiday_type    locale locale_name         description  \
# 0               NaN      Holiday  National     Ecuador  Primer dia del ano
# 1               NaN      Holiday  National     Ecuador  Primer dia del ano
# 2               NaN      Holiday  National     Ecuador  Primer dia del ano
# 3               NaN      Holiday  National     Ecuador  Primer dia del ano
# 4               NaN      Holiday  National     Ecuador  Primer dia del ano
# ...             ...          ...       ...         ...                 ...
# 3008770       47.57          NaN       NaN         NaN                 NaN
# 3008771       47.57          NaN       NaN         NaN                 NaN
# 3008772       47.57          NaN       NaN         NaN                 NaN
# 3008773       47.57          NaN       NaN         NaN                 NaN
# 3008774       47.57          NaN       NaN         NaN                 NaN
#
#         transferred
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 3008770         NaN
# 3008771         NaN
# 3008772         NaN
# 3008773         NaN
# 3008774         NaN
#
# [3008775 rows x 17 columns]

# %%
def fill_in_nulls(df):
    # check for NA
    df['transactions'].fillna(0, inplace=True)
    df['dcoilwtico'].fillna(0, inplace=True)
    df['transferred'].fillna(False, inplace=True)
    df.fillna('None', inplace=True)  # fillna for the rest are strings
    return df

# %%
fill_in_nulls(df)
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3008770  3000883  2017-08-15          9                     POULTRY   438.133
# 3008771  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3008772  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3008773  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3008774  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state store_type  cluster  transactions  \
# 0                  0  Quito  Pichincha          D       13           0.0
# 1                  0  Quito  Pichincha          D       13           0.0
# 2                  0  Quito  Pichincha          D       13           0.0
# 3                  0  Quito  Pichincha          D       13           0.0
# 4                  0  Quito  Pichincha          D       13           0.0
# ...              ...    ...        ...        ...      ...           ...
# 3008770            0  Quito  Pichincha          B        6        2155.0
# 3008771            1  Quito  Pichincha          B        6        2155.0
# 3008772          148  Quito  Pichincha          B        6        2155.0
# 3008773            8  Quito  Pichincha          B        6        2155.0
# 3008774            0  Quito  Pichincha          B        6        2155.0
#
#          dcoilwtico holiday_type    locale locale_name         description  \
# 0              0.00      Holiday  National     Ecuador  Primer dia del ano
# 1              0.00      Holiday  National     Ecuador  Primer dia del ano
# 2              0.00      Holiday  National     Ecuador  Primer dia del ano
# 3              0.00      Holiday  National     Ecuador  Primer dia del ano
# 4              0.00      Holiday  National     Ecuador  Primer dia del ano
# ...             ...          ...       ...         ...                 ...
# 3008770       47.57         None      None        None                None
# 3008771       47.57         None      None        None                None
# 3008772       47.57         None      None        None                None
# 3008773       47.57         None      None        None                None
# 3008774       47.57         None      None        None                None
#
#          transferred
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 3008770        False
# 3008771        False
# 3008772        False
# 3008773        False
# 3008774        False
#
# [3008775 rows x 17 columns]

# %%
store1 = df[df['store_nbr']==1]
store1
# Out:
#               id        date  store_nbr                      family  \
# 0              0  2013-01-01          1                  AUTOMOTIVE
# 1              1  2013-01-01          1                   BABY CARE
# 2              2  2013-01-01          1                      BEAUTY
# 3              3  2013-01-01          1                   BEVERAGES
# 4              4  2013-01-01          1                       BOOKS
# ...          ...         ...        ...                         ...
# 3007021  2999134  2017-08-15          1                     POULTRY
# 3007022  2999135  2017-08-15          1              PREPARED FOODS
# 3007023  2999136  2017-08-15          1                     PRODUCE
# 3007024  2999137  2017-08-15          1  SCHOOL AND OFFICE SUPPLIES
# 3007025  2999138  2017-08-15          1                     SEAFOOD
#
#                sales  onpromotion   city      state store_type  cluster  \
# 0           0.000000            0  Quito  Pichincha          D       13
# 1           0.000000            0  Quito  Pichincha          D       13
# 2           0.000000            0  Quito  Pichincha          D       13
# 3           0.000000            0  Quito  Pichincha          D       13
# 4           0.000000            0  Quito  Pichincha          D       13
# ...              ...          ...    ...        ...        ...      ...
# 3007021   234.892000            0  Quito  Pichincha          D       13
# 3007022    42.822998            0  Quito  Pichincha          D       13
# 3007023  2240.230000            7  Quito  Pichincha          D       13
# 3007024     0.000000            0  Quito  Pichincha          D       13
# 3007025    22.487000            0  Quito  Pichincha          D       13
#
#          transactions  dcoilwtico holiday_type    locale locale_name  \
# 0                 0.0        0.00      Holiday  National     Ecuador
# 1                 0.0        0.00      Holiday  National     Ecuador
# 2                 0.0        0.00      Holiday  National     Ecuador
# 3                 0.0        0.00      Holiday  National     Ecuador
# 4                 0.0        0.00      Holiday  National     Ecuador
# ...               ...         ...          ...       ...         ...
# 3007021        1693.0       47.57         None      None        None
# 3007022        1693.0       47.57         None      None        None
# 3007023        1693.0       47.57         None      None        None
# 3007024        1693.0       47.57         None      None        None
# 3007025        1693.0       47.57         None      None        None
#
#                 description  transferred
# 0        Primer dia del ano        False
# 1        Primer dia del ano        False
# 2        Primer dia del ano        False
# 3        Primer dia del ano        False
# 4        Primer dia del ano        False
# ...                     ...          ...
# 3007021                None        False
# 3007022                None        False
# 3007023                None        False
# 3007024                None        False
# 3007025                None        False
#
# [55704 rows x 17 columns]

# %%
store1['holiday_type'].unique()
# Out:
# array(['Holiday', 'None', 'Work Day', 'Additional', 'Event', 'Transfer',
#        'Bridge'], dtype=object)

# %%
cols = store1.columns.tolist()
cols
# Out:
# ['id',
#  'date',
#  'store_nbr',
#  'family',
#  'sales',
#  'onpromotion',
#  'city',
#  'state',
#  'store_type',
#  'cluster',
#  'transactions',
#  'dcoilwtico',
#  'holiday_type',
#  'locale',
#  'locale_name',
#  'description',
#  'transferred']

# %%
cols2 = [c for c in cols if c not in ['locale_name','locale']]

# %%
cols2.append('locale')
cols2
# Out:
# ['id',
#  'date',
#  'store_nbr',
#  'family',
#  'sales',
#  'onpromotion',
#  'city',
#  'state',
#  'store_type',
#  'cluster',
#  'transactions',
#  'dcoilwtico',
#  'holiday_type',
#  'description',
#  'transferred',
#  'locale']

# %%
try1 = store1.groupby(by=cols2)['locale_name'].aggregate(lambda x: x).unstack(fill_value='None').reset_index()
try1
# Out:
# locale       id        date  store_nbr                      family  \
# 0             0  2013-01-01          1                  AUTOMOTIVE
# 1             1  2013-01-01          1                   BABY CARE
# 2             2  2013-01-01          1                      BEAUTY
# 3             3  2013-01-01          1                   BEVERAGES
# 4             4  2013-01-01          1                       BOOKS
# ...         ...         ...        ...                         ...
# 55699   2999134  2017-08-15          1                     POULTRY
# 55700   2999135  2017-08-15          1              PREPARED FOODS
# 55701   2999136  2017-08-15          1                     PRODUCE
# 55702   2999137  2017-08-15          1  SCHOOL AND OFFICE SUPPLIES
# 55703   2999138  2017-08-15          1                     SEAFOOD
#
# locale        sales  onpromotion   city      state store_type  cluster  \
# 0          0.000000            0  Quito  Pichincha          D       13
# 1          0.000000            0  Quito  Pichincha          D       13
# 2          0.000000            0  Quito  Pichincha          D       13
# 3          0.000000            0  Quito  Pichincha          D       13
# 4          0.000000            0  Quito  Pichincha          D       13
# ...             ...          ...    ...        ...        ...      ...
# 55699    234.892000            0  Quito  Pichincha          D       13
# 55700     42.822998            0  Quito  Pichincha          D       13
# 55701   2240.230000            7  Quito  Pichincha          D       13
# 55702      0.000000            0  Quito  Pichincha          D       13
# 55703     22.487000            0  Quito  Pichincha          D       13
#
# locale  transactions  dcoilwtico holiday_type         description  \
# 0                0.0        0.00      Holiday  Primer dia del ano
# 1                0.0        0.00      Holiday  Primer dia del ano
# 2                0.0        0.00      Holiday  Primer dia del ano
# 3                0.0        0.00      Holiday  Primer dia del ano
# 4                0.0        0.00      Holiday  Primer dia del ano
# ...              ...         ...          ...                 ...
# 55699         1693.0       47.57         None                None
# 55700         1693.0       47.57         None                None
# 55701         1693.0       47.57         None                None
# 55702         1693.0       47.57         None                None
# 55703         1693.0       47.57         None                None
#
# locale  transferred Local National  None
# 0             False  None  Ecuador  None
# 1             False  None  Ecuador  None
# 2             False  None  Ecuador  None
# 3             False  None  Ecuador  None
# 4             False  None  Ecuador  None
# ...             ...   ...      ...   ...
# 55699         False  None     None  None
# 55700         False  None     None  None
# 55701         False  None     None  None
# 55702         False  None     None  None
# 55703         False  None     None  None
#
# [55704 rows x 18 columns]
